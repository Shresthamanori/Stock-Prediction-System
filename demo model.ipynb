# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data
import yfinance as yf
import datetime as date

# %%
import datetime
date = datetime.date.today()

# %%
start = '2010-01-01'
end = '2019-12-31'
ticker = yf.Ticker('TSLA')
df = ticker.history(start=start, end=end)
df.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
df.tail()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2019-12-23 00:00:00-05:00  27.452000  28.134001  27.333332  27.948000
# 2019-12-24 00:00:00-05:00  27.890667  28.364668  27.512667  28.350000
# 2019-12-26 00:00:00-05:00  28.527332  28.898666  28.423332  28.729334
# 2019-12-27 00:00:00-05:00  29.000000  29.020666  28.407333  28.691999
# 2019-12-30 00:00:00-05:00  28.586000  28.600000  27.284000  27.646667
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-12-23 00:00:00-05:00  199794000        0.0           0.0
# 2019-12-24 00:00:00-05:00  120820500        0.0           0.0
# 2019-12-26 00:00:00-05:00  159508500        0.0           0.0
# 2019-12-27 00:00:00-05:00  149185500        0.0           0.0
# 2019-12-30 00:00:00-05:00  188796000        0.0           0.0

# %%
df = df.reset_index()
df.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
df = df.drop(['Date'], axis = 1)
df.head()
# Out:
#        Open      High       Low     Close     Volume  Dividends  Stock Splits
# 0  1.266667  1.666667  1.169333  1.592667  281494500        0.0           0.0
# 1  1.719333  2.028000  1.553333  1.588667  257806500        0.0           0.0
# 2  1.666667  1.728000  1.351333  1.464000  123282000        0.0           0.0
# 3  1.533333  1.540000  1.247333  1.280000   77097000        0.0           0.0
# 4  1.333333  1.333333  1.055333  1.074000  103003500        0.0           0.0

# %%
plt.plot(df.Close)

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2388    18.778527
# 2389    18.905800
# 2390    19.040880
# 2391    19.173967
# 2392    19.294820
# Name: Close, Length: 2393, dtype: float64

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2388    17.430070
# 2389    17.477367
# 2390    17.524693
# 2391    17.571500
# 2392    17.617923
# Name: Close, Length: 2393, dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data
import yfinance as yf
from keras.models import load_model
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14192\2407675716.py in <module>
#       4 import pandas_datareader as data
#       5 import yfinance as yf
# ----> 6 from keras.models import load_model
#       7 import streamlit as st
#
# ~\anaconda3\lib\site-packages\keras\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# ~\anaconda3\lib\site-packages\keras\__internal__\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# ~\anaconda3\lib\site-packages\keras\__internal__\backend\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# ~\anaconda3\lib\site-packages\keras\src\__init__.py in <module>
#      19 """
#      20 from keras.src import distribute
# ---> 21 from keras.src import models
#      22 from keras.src.engine.input_layer import Input
#      23 from keras.src.engine.sequential import Sequential
#
# ~\anaconda3\lib\site-packages\keras\src\models\__init__.py in <module>
#      16
#      17
# ---> 18 from keras.src.engine.functional import Functional
#      19 from keras.src.engine.sequential import Sequential
#      20 from keras.src.engine.training import Model
#
# ~\anaconda3\lib\site-packages\keras\src\engine\functional.py in <module>
#      21 import warnings
#      22
# ---> 23 import tensorflow.compat.v2 as tf
#      24
#      25 from keras.src import backend
#
# ~\anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      36 import typing as _typing
#      37
# ---> 38 from tensorflow.python.tools import module_util as _module_util
#      39 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40
#
# ~\anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      35
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      38
#      39 # pylint: enable=wildcard-import
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in <module>
#      34 from tensorflow.python.client import pywrap_tf_session
#      35 from tensorflow.python.eager import cancellation
# ---> 36 from tensorflow.python.eager import execute
#      37 from tensorflow.python.eager import executor
#      38 from tensorflow.python.eager import monitoring
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in <module>
#      19 from tensorflow.python import pywrap_tfe
#      20 from tensorflow.python.eager import core
# ---> 21 from tensorflow.python.framework import dtypes
#      22 from tensorflow.python.framework import tensor_conversion_registry
#      23 from tensorflow.python.framework import tensor_shape
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py in <module>
#      36 from tensorflow.python.framework import cpp_shape_inference_pb2
#      37
# ---> 38 _np_bfloat16 = pywrap_bfloat16.bfloat16_type()
#      39 _np_float8_e4m3fn = _pywrap_float8.TF_float8_e4m3fn_type()
#      40 _np_float8_e5m2 = _pywrap_float8.TF_float8_e5m2_type()
#
# TypeError: Unable to convert function return value to a Python type! The signature was
# 	() -> handle

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2388    17.430070
# 2389    17.477367
# 2390    17.524693
# 2391    17.571500
# 2392    17.617923
# Name: Close, Length: 2393, dtype: float64

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10584\1472378890.py in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (2393, 7)

# %%
# spliiting data into training and testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10584\371865530.py in <module>
#       2
#       3 data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
# ----> 4 data_testing = pd.DataFrame(df['Close'][(len(df)*0.70):int(len(df))])
#       5
#       6 print(data_training.shape)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     982             return self._get_values(key)
#     983
# --> 984         return self._get_with(key)
#     985
#     986     def _get_with(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     989             # _convert_slice_indexer to determine if this slice is positional
#     990             #  or label based, and if the latter, convert to positional
# --> 991             slobj = self.index._convert_slice_indexer(key, kind="getitem")
#     992             return self._slice(slobj)
#     993         elif isinstance(key, ABCDataFrame):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\numeric.py in _convert_slice_indexer(self, key, kind)
#     277             return self.slice_indexer(key.start, key.stop, key.step)
#     278
# --> 279         return super()._convert_slice_indexer(key, kind=kind)
#     280
#     281     @doc(Index._maybe_cast_slice_bound)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
#    4053             """
#    4054             if self.is_integer() or is_index_slice:
# -> 4055                 self._validate_indexer("slice", key.start, "getitem")
#    4056                 self._validate_indexer("slice", key.stop, "getitem")
#    4057                 self._validate_indexer("slice", key.step, "getitem")
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_indexer(self, form, key, kind)
#    6320
#    6321         if key is not None and not is_integer(key):
# -> 6322             raise self._invalid_indexer(form, key)
#    6323
#    6324     def _maybe_cast_slice_bound(self, label, side: str_t, kind=no_default):
#
# TypeError: cannot do slice indexing on RangeIndex with these indexers [1675.1] of type float

# %%
data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (1675, 1)
# (718, 1)

# %%
data_training.head()
# Out:
#       Close
# 0  1.592667
# 1  1.588667
# 2  1.464000
# 3  1.280000
# 4  1.074000

# %%
data_testing.head()
# Out:
#           Close
# 1675  17.066000
# 1676  17.133333
# 1677  16.415333
# 1678  16.666000
# 1679  16.667999

# %%
# scaling the data

from sklearn.preprocessing import MinMaxScalar
scaler = MinMaxScaler(feature_range=(0,1))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10584\851108829.py in <module>
#       1 # scaling the data
#       2
# ----> 3 from sklearn.preprocessing import MinMaxScalar
#       4 scaler = MinMaxScaler(feature_range=(0,1))
#
# ImportError: cannot import name 'MinMaxScalar' from 'sklearn.preprocessing' (C:\Users\hp\anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
from sklearn.preprocessing import MinMaxScalar
scaler = MinMaxScaler(feature_range=(0,1))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10584\178712180.py in <module>
# ----> 1 from sklearn.preprocessing import MinMaxScalar
#       2 scaler = MinMaxScaler(feature_range=(0,1))
#
# ImportError: cannot import name 'MinMaxScalar' from 'sklearn.preprocessing' (C:\Users\hp\anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
import MinMaxScalar as mn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10584\481797351.py in <module>
# ----> 1 import MinMaxScalar as mn
#
# ModuleNotFoundError: No module named 'MinMaxScalar'

# %%
from sklearn.preprocessing import MinMaxScalar
scaler = MinMaxScaler(feature_range=(0,1))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10584\178712180.py in <module>
# ----> 1 from sklearn.preprocessing import MinMaxScalar
#       2 scaler = MinMaxScaler(feature_range=(0,1))
#
# ImportError: cannot import name 'MinMaxScalar' from 'sklearn.preprocessing' (C:\Users\hp\anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.02993639],
#        [0.02971437],
#        [0.02279457],
#        ...,
#        [0.94889733],
#        [0.96799146],
#        [0.95363383]])

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# ML model

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences = True,
              input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))



model.add(LSTM(units = 60, activation = 'relu', return_sequences = True,))
model.add(Dropout(0.3))



model.add(LSTM(units = 80, activation = 'relu', return_sequences = True,))
model.add(Dropout(0.4))



model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))


model.add(Dense(units = 1))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 100, 50)           10400
#
#  dropout_4 (Dropout)         (None, 100, 50)           0
#
#  lstm_5 (LSTM)               (None, 100, 60)           26640
#
#  dropout_5 (Dropout)         (None, 100, 60)           0
#
#  lstm_6 (LSTM)               (None, 100, 80)           45120
#
#  dropout_6 (Dropout)         (None, 100, 80)           0
#
#  lstm_7 (LSTM)               (None, 120)               96480
#
#  dropout_7 (Dropout)         (None, 120)               0
#
#  dense_1 (Dense)             (None, 1)                 121
#
# =================================================================
# Total params: 178761 (698.29 KB)
# Trainable params: 178761 (698.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train , y_train, epochs = 50)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 38s 463ms/step - loss: 0.0790
# Epoch 2/50
# 50/50 [==============================] - 21s 426ms/step - loss: 0.0149
# Epoch 3/50
# 50/50 [==============================] - 21s 415ms/step - loss: 0.0112
# Epoch 4/50
# 50/50 [==============================] - 21s 415ms/step - loss: 0.0108
# Epoch 5/50
# 50/50 [==============================] - 21s 427ms/step - loss: 0.0113
# Epoch 6/50
# 50/50 [==============================] - 22s 443ms/step - loss: 0.0109
# Epoch 7/50
# 50/50 [==============================] - 22s 435ms/step - loss: 0.0088
# Epoch 8/50
# 50/50 [==============================] - 22s 445ms/step - loss: 0.0095
# Epoch 9/50
# 50/50 [==============================] - 21s 429ms/step - loss: 0.0092
# Epoch 10/50
# 50/50 [==============================] - 22s 443ms/step - loss: 0.0104
# Epoch 11/50
# 50/50 [==============================] - 26s 518ms/step - loss: 0.0091
# Epoch 12/50
# 50/50 [==============================] - 38s 754ms/step - loss: 0.0081
# Epoch 13/50
# 50/50 [==============================] - 38s 758ms/step - loss: 0.0087
# Epoch 14/50
# 50/50 [==============================] - 38s 761ms/step - loss: 0.0071
# Epoch 15/50
# 50/50 [==============================] - 38s 754ms/step - loss: 0.0077
# Epoch 16/50
# 50/50 [==============================] - 38s 754ms/step - loss: 0.0083
# Epoch 17/50
# 50/50 [==============================] - 39s 775ms/step - loss: 0.0076
# Epoch 18/50
# 50/50 [==============================] - 40s 799ms/step - loss: 0.0067
# Epoch 19/50
# 50/50 [==============================] - 38s 762ms/step - loss: 0.0074
# Epoch 20/50
# 50/50 [==============================] - 39s 787ms/step - loss: 0.0064
# Epoch 21/50
# 50/50 [==============================] - 41s 820ms/step - loss: 0.0068
# Epoch 22/50
# 50/50 [==============================] - 38s 760ms/step - loss: 0.0064
# Epoch 23/50
# 50/50 [==============================] - 39s 776ms/step - loss: 0.0068
# Epoch 24/50
# 50/50 [==============================] - 42s 841ms/step - loss: 0.0062
# Epoch 25/50
# 50/50 [==============================] - 42s 848ms/step - loss: 0.0058
# Epoch 26/50
# 50/50 [==============================] - 41s 811ms/step - loss: 0.0056
# Epoch 27/50
# 50/50 [==============================] - 39s 773ms/step - loss: 0.0059
# Epoch 28/50
# 50/50 [==============================] - 38s 764ms/step - loss: 0.0056
# Epoch 29/50
# 50/50 [==============================] - 37s 749ms/step - loss: 0.0063
# Epoch 30/50
# 50/50 [==============================] - 44s 878ms/step - loss: 0.0057
# Epoch 31/50
# 50/50 [==============================] - 45s 904ms/step - loss: 0.0054
# Epoch 32/50
# 50/50 [==============================] - 41s 831ms/step - loss: 0.0055
# Epoch 33/50
# 50/50 [==============================] - 41s 810ms/step - loss: 0.0055
# Epoch 34/50
# 50/50 [==============================] - 35s 701ms/step - loss: 0.0058
# Epoch 35/50
# 50/50 [==============================] - 36s 717ms/step - loss: 0.0053
# Epoch 36/50
# 50/50 [==============================] - 37s 734ms/step - loss: 0.0056
# Epoch 37/50
# 50/50 [==============================] - 40s 805ms/step - loss: 0.0049
# Epoch 38/50
# 50/50 [==============================] - 37s 740ms/step - loss: 0.0049
# Epoch 39/50
# 50/50 [==============================] - 38s 761ms/step - loss: 0.0059
# Epoch 40/50
# 50/50 [==============================] - 39s 774ms/step - loss: 0.0057
# Epoch 41/50
# 50/50 [==============================] - 37s 732ms/step - loss: 0.0052
# Epoch 42/50
# 50/50 [==============================] - 37s 751ms/step - loss: 0.0053
# Epoch 43/50
# 50/50 [==============================] - 39s 773ms/step - loss: 0.0053
# Epoch 44/50
# 50/50 [==============================] - 38s 755ms/step - loss: 0.0062
# Epoch 45/50
# 50/50 [==============================] - 38s 759ms/step - loss: 0.0053
# Epoch 46/50
# 50/50 [==============================] - 38s 753ms/step - loss: 0.0054
# Epoch 47/50
# 50/50 [==============================] - 38s 764ms/step - loss: 0.0052
# Epoch 48/50
# 50/50 [==============================] - 39s 783ms/step - loss: 0.0050
# Epoch 49/50
# 50/50 [==============================] - 35s 707ms/step - loss: 0.0049
# Epoch 50/50
# 50/50 [==============================] - 37s 736ms/step - loss: 0.0052

# %%
model.save('keras_model.h5')

# %%
data_testing.head()
# Out:
#           Close
# 1675  17.066000
# 1676  17.133333
# 1677  16.415333
# 1678  16.666000
# 1679  16.667999

# %%
past_100_days = data_training.tail(100)

# %%
final_df = past_100_days.append(data_testing, ignore_index = True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10584\3299050086.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = past_100_days.append(data_testing, ignore_index = True)

# %%
final_df.head()
# Out:
#        Close
# 0  13.380000
# 1  13.602000
# 2  14.246667
# 3  14.094000
# 4  13.897333

# %%
input_data = scaler.fit_transform(final_df)

# %%
input_data.shape
# Out:
# (818, 1)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100: i])
    y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (718, 100, 1)
# (718,)

# %%
# Making predictions

y_predicted = model.predict(x_test)
# Out:
# 23/23 [==============================] - 6s 142ms/step

# %%
y_predicted.shape
# Out:
# (718, 1)

# %%
y_test
# Out:
# array([0.30567133, 0.30967974, 0.26693653, 0.281859  , 0.28197799,
#        0.2838037 , 0.28812958, 0.28670083, 0.27630273, 0.26947656,
#        0.26165822, 0.25685602, 0.26669843, 0.31364852, 0.30463954,
#        0.32972177, 0.32753896, 0.32920582, 0.28459739, 0.30178203,
#        0.30086912, 0.33412713, 0.36214635, 0.39084026, 0.39056242,
#        0.39270549, 0.39421361, 0.47446122, 0.49501933, 0.46049141,
#        0.47517566, 0.49041548, 0.5295075 , 0.51490262, 0.46779379,
#        0.49620986, 0.48604997, 0.48132713, 0.50224234, 0.49029649,
#        0.50255981, 0.51220386, 0.53506365, 0.52069688, 0.51458503,
#        0.53617493, 0.57094095, 0.55530416, 0.52407034, 0.46231689,
#        0.51347387, 0.50887014, 0.5647101 , 0.58042625, 0.5720126 ,
#        0.57879902, 0.54335831, 0.54784305, 0.50458389, 0.53216652,
#        0.52331628, 0.52141132, 0.49565428, 0.52089536, 0.54712861,
#        0.58010878, 0.61963726, 0.64309238, 0.64055247, 0.63848877,
#        0.6681351 , 0.6900821 , 0.71706953, 0.75814587, 0.70782233,
#        0.7145295 , 0.78175973, 0.80045238, 0.77933881, 0.76370203,
#        0.75735207, 0.76703574, 0.78354558, 0.80819146, 0.81152517,
#        0.78787158, 0.72786447, 0.76306696, 0.72143504, 0.72484812,
#        0.6891693 , 0.58784774, 0.51537883, 0.53280147, 0.544033  ,
#        0.5883637 , 0.59749179, 0.57324287, 0.59058614, 0.55800293,
#        0.59241185, 0.58058499, 0.59907928, 0.5930468 , 0.64908524,
#        0.63749649, 0.65436354, 0.61709724, 0.61951815, 0.57348098,
#        0.55800293, 0.58308528, 0.6672223 , 0.70619521, 0.69928956,
#        0.73917526, 0.73246809, 0.70020236, 0.71000514, 0.73353962,
#        0.72770562, 0.73000754, 0.68639117, 0.66869068, 0.63059095,
#        0.64444176, 0.68976463, 0.69039969, 0.67103223, 0.66154704,
#        0.66829384, 0.69139186, 0.7021868 , 0.70020236, 0.67714408,
#        0.65706231, 0.68119223, 0.65257769, 0.73310315, 0.72937248,
#        [0.33654243],
#        [0.33573696],
#        [0.33515006],
#        [0.33486804],
#        [0.33499604],
#        [0.3356278 ],
#        [0.3368294 ],
#        [0.33881176],
#        [0.34194034],
#        [0.3464666 ],
#        [0.35253042],
#        [0.36020273],
#        [0.369895  ],
#        [0.38196868],
#        [0.39576042],
#        [0.41065168],
#        [0.42576253],
#        [0.43997353],
#        [0.45279175],
#        [0.46396643],
#        [0.47354108],
#        [0.48176408],
#        [0.4891489 ],
#        [0.4959746 ],
#        [0.50227463],
#        [0.5082742 ],
#        [0.5148328 ],
#        [0.5223347 ],
#        [0.5300776 ],
#        [0.5361796 ],
#        [0.540097  ],
#        [0.54192305],
#        [0.54269683],
#        [0.5438475 ],
#        [0.546394  ],
#        [0.5508514 ],
#        [0.55644345],
#        [0.5622083 ],
#        [0.56654525],
#        [0.5688287 ],
#        [0.56898034],
#        [0.56727725],
#        [0.5639719 ],
#        [0.5596467 ],
#        [0.5551171 ],
#        [0.5515325 ],
#        [0.5506055 ],
#        [0.55403334],
#        [0.5624373 ],
#        [0.57536644],
#        [0.59206057],
#        [0.6116513 ],
#        [0.6333581 ],
#        [0.65677077],
#        [0.68013495],
#        [0.7017699 ],
#        [0.72161126],
#        [0.74002504],
#        [0.75670004],
#        [0.7708879 ],
#        [0.7818694 ],
#        [0.78957367],
#        [0.7946199 ],
#        [0.79814136],
#        [0.801059  ],
#        [0.80340445],
#        [0.8034978 ],
#        [0.80116343],
#        [0.7959292 ],
#        [0.78803253],
#        [0.7774514 ],
#        [0.76305485],
#        [0.7447401 ],
#        [0.7234114 ],
#        [0.70033264],
#        [0.6770418 ],
#        [0.65470505],
#        [0.63407344],
#        [0.6158017 ],
#        [0.6001411 ],
#        [0.58750206],
#        [0.5780913 ],
#        [0.57227904],
#        [0.5702254 ],
#        [0.5726784 ],
#        [0.5796804 ],
#        [0.59086514],
#        [0.604471  ],
#        [0.61857617],
#        [0.6305295 ],
#        [0.6381847 ],
#        [0.6411696 ],
#        [0.6416771 ],
#        [0.6425953 ],
#        [0.6459069 ],
#        [0.653105  ],
#        [0.6643929 ],
#        [0.67839956],
#        [0.6935102 ],
#        [0.7086337 ],
#        [0.7227841 ],
#        [0.73526245],
#        [0.74450153],
#        [0.7491285 ],
#        [0.7479756 ],
#        [0.7414616 ],
#        [0.73172367],
#        [0.7208369 ],
#        [0.7101113 ],
#        [0.70026416],
#        [0.69185436],
#        [0.6857367 ],
#        [0.6826839 ],
#        [0.682905  ],
#        [0.68552166],
#        [0.6889357 ],
#        [0.6923802 ],
#        [0.69480014],
#        [0.6972406 ],
#        [0.70070714],
#        [0.70596504],
#        [0.71394914],
#        [0.72496057],
#        [0.7388511 ],
#        [0.75403273],
#        [0.76869786],
#        [0.78063023],
#        [0.7869649 ],
#        [0.78609496],
#        [0.77837825],
#        [0.76509106],
#        [0.7479278 ],
#        [0.7287047 ],
#        [0.70901966],
#        [0.69062877],
#        [0.6756481 ],
#        [0.66573226],
#        [0.6617948 ],
#        [0.6624253 ],
#        [0.66683096],
#        [0.6740801 ],
#        [0.68323314],
#        [0.69329447],
#        [0.7028322 ],
#        [0.7112157 ],
#        [0.71853065],
#        [0.72418743],
#        [0.7271164 ],
#        [0.72605187],
#        [0.7207602 ],
#        [0.7111625 ],
#        [0.6979838 ],
#        [0.682208  ],
#        [0.664936  ],
#        [0.64760804],
#        [0.6310852 ],
#        [0.6153593 ],
#        [0.6004939 ],
#        [0.5865609 ],
#        [0.5736764 ],
#        [0.56192744],
#        [0.5513729 ],
#        [0.5420382 ],
#        [0.5341811 ],
#        [0.5279335 ],
#        [0.52338254],
#        [0.5205449 ],
#        [0.5194675 ],
#        [0.51980597],
#        [0.5215891 ],
#        [0.5245026 ],
#        [0.52834004],
#        [0.53296494],
#        [0.53820586],
#        [0.5430575 ],
#        [0.5467228 ],
#        [0.54875547],
#        [0.54907966],
#        [0.5478519 ],
#        [0.5457268 ],
#        [0.5432687 ],
#        [0.5410786 ],
#        [0.5404159 ],
#        [0.5432355 ],
#        [0.5506248 ],
#        [0.56254303],
#        [0.5783971 ],
#        [0.59665334],
#        [0.6147676 ],
#        [0.6303347 ],
#        [0.6420882 ],
#        [0.6490989 ],
#        [0.65064037],
#        [0.6467853 ],
#        [0.6387272 ],
#        [0.62775064],
#        [0.6153673 ],
#        [0.60278624],
#        [0.5907916 ],
#        [0.57993025],
#        [0.5714909 ],
#        [0.56683886],
#        [0.5669558 ],
#        [0.5721166 ],
#        [0.5816289 ],
#        [0.59449524],
#        [0.6099097 ],
#        [0.6267167 ],
#        [0.6440227 ],
#        [0.66104996],
#        [0.6771389 ],
#        [0.69101316],
#        [0.7009044 ],
#        [0.7063373 ],
#        [0.70823866],
#        [0.7074659 ],
#        [0.7056271 ],
#        [0.7035545 ],
#        [0.70116657],
#        [0.6973019 ],
#        [0.69135094],
#        [0.68421656],
#        [0.67491543],
#        [0.6630293 ],
#        [0.64913297],
#        [0.63434094],
#        [0.6196731 ],
#        [0.6064082 ],
#        [0.5959001 ],
#        [0.5892546 ],
#        [0.5870308 ],
#        [0.5898789 ],
#        [0.5981253 ],
#        [0.6116081 ],
#        [0.62893087],
#        [0.6474268 ],
#        [0.66344017],
#        [0.6748629 ],
#        [0.6808543 ],
#        [0.6812388 ],
#        [0.67705405],
#        [0.6695035 ],
#        [0.6596955 ],
#        [0.64994085],
#        [0.6420716 ],
#        [0.635993  ],
#        [0.63095033],
#        [0.6259512 ],
#        [0.6199469 ],
#        [0.6124211 ],
#        [0.6037898 ],
#        [0.5944567 ],
#        [0.5846735 ],
#        [0.57475215],
#        [0.56469566],
#        [0.5543722 ],
#        [0.543885  ],
#        [0.5333697 ],
#        [0.52302074],
#        [0.51312774],
#        [0.5040813 ],
#        [0.49619555],
#        [0.48953688],
#        [0.4841292 ],
#        [0.48006338],
#        [0.47730577],
#        [0.47588325],
#        [0.4755237 ],
#        [0.4757496 ],
#        [0.47626603],
#        [0.47700202],
#        [0.47779238],
#        [0.47842866],
#        [0.4787665 ],
#        [0.47872448],
#        [0.47832984],
#        [0.47772068],
#        [0.47704566],
#        [0.47648436],
#        [0.47624862],
#        [0.47622782],
#        [0.47637212],
#        [0.47680068],
#        [0.4776399 ],
#        [0.47908068],
#        [0.481246  ],
#        [0.4839756 ],
#        [0.48673505],
#        [0.48893648],
#        [0.49032956],
#        [0.49084067],
#        [0.4904464 ],
#        [0.48929268],
#        [0.4875098 ],
#        [0.48525262],
#        [0.4826647 ],
#        [0.47986192],
#        [0.4768979 ],
#        [0.4738682 ],
#        [0.47086924],
#        [0.4680484 ],
#        [0.46559352],
#        [0.4636172 ],
#        [0.46269208],
#        [0.46361363],
#        [0.46732098],
#        [0.475186  ],
#        [0.4885655 ],
#        [0.5079681 ],
#        [0.5334086 ],
#        [0.56375337],
#        [0.59785295],
#        [0.63248485],
#        [0.6651863 ],
#        [0.6927972 ],
#        [0.71198004],
#        [0.7214092 ],
#        [0.72245026],
#        [0.7175665 ],
#        [0.70961547],
#        [0.70038635],
#        [0.6904937 ],
#        [0.67872363],
#        [0.6648033 ],
#        [0.6492274 ],
#        [0.6329831 ],
#        [0.6170427 ],
#        [0.60210824],
#        [0.5886608 ],
#        [0.5770704 ],
#        [0.5672535 ],
#        [0.559475  ],
#        [0.5541252 ],
#        [0.55127424],
#        [0.5503197 ],
#        [0.54989684],
#        [0.5488456 ],
#        [0.54697144],
#        [0.5444058 ],
#        [0.5411394 ],
#        [0.5371485 ],
#        [0.5326181 ],
#        [0.52785426],
#        [0.52434933],
#        [0.52450824],
#        [0.5302232 ],
#        [0.5444272 ],
#        [0.5677037 ],
#        [0.59720826],
#        [0.6292381 ],
#        [0.66038054],
#        [0.6872439 ],
#        [0.7068862 ],
#        [0.71783805],
#        [0.71846855],
#        [0.7103733 ],
#        [0.6962337 ],
#        [0.67846394],
#        [0.6590982 ],
#        [0.63979715],
#        [0.62158996],
#        [0.6049377 ],
#        [0.58989054],
#        [0.5763702 ],
#        [0.56425476],
#        [0.5532857 ],
#        [0.54321575],
#        [0.53385735],
#        [0.5250035 ],
#        [0.51665306],
#        [0.508834  ],
#        [0.50166714],
#        [0.4952603 ],
#        [0.48972952],
#        [0.4851284 ],
#        [0.48132104],
#        [0.47826767],
#        [0.4759953 ],
#        [0.47458154],
#        [0.47412515],
#        [0.4746288 ],
#        [0.4761926 ],
#        [0.47887373],
#        [0.4814883 ],
#        [0.48392916],
#        [0.48617452],
#        [0.48807126],
#        [0.4893433 ],
#        [0.48964316],
#        [0.48875284],
#        [0.48676866],
#        [0.48384923],
#        [0.48013532],
#        [0.47564447],
#        [0.47040617],
#        [0.46457142],
#        [0.45832986],
#        [0.45184666],
#        [0.44524884],
#        [0.43864074],
#        [0.43226624],
#        [0.4263966 ],
#        [0.42154872],
#        [0.41873717],
#        [0.41996333],
#        [0.42772728],
#        [0.4436379 ],
#        [0.46748638],
#        [0.49757522],
#        [0.5310902 ],
#        [0.5650325 ],
#        [0.5973364 ],
#        [0.6267624 ],
#        [0.6524792 ],
#        [0.67211676],
#        [0.68496877],
#        [0.6918986 ],
#        [0.6946826 ],
#        [0.69551146],
#        [0.6960105 ],
#        [0.69655174],
#        [0.69619095],
#        [0.6930823 ],
#        [0.6878858 ],
#        [0.6816764 ],
#        [0.67586416],
#        [0.67092687],
#        [0.6678216 ],
#        [0.66770834],
#        [0.6712002 ],
#        [0.6783892 ],
#        [0.68834126],
#        [0.7002568 ],
#        [0.7132961 ],
#        [0.72652924],
#        [0.7397938 ],
#        [0.7519495 ],
#        [0.76024765],
#        [0.76205486],
#        [0.7565148 ],
#        [0.74413127],
#        [0.72665006],
#        [0.7055889 ],
#        [0.68291706],
#        [0.66015905],
#        [0.6386424 ],
#        [0.6194946 ],
#        [0.60283786],
#        [0.58822846],
#        [0.57566   ],
#        [0.5658569 ],
#        [0.5598947 ],
#        [0.55899745],
#        [0.56406075],
#        [0.57510155],
#        [0.59007543],
#        [0.6073498 ],
#        [0.6255607 ],
#        [0.6435797 ],
#        [0.65636516],
#        [0.66077065],
#        [0.65711516],
#        [0.6471721 ],
#        [0.63309866],
#        [0.6168136 ],
#        [0.5997345 ],
#        [0.58302635],
#        [0.5674685 ],
#        [0.5536544 ],
#        [0.5420266 ],
#        [0.53320134],
#        [0.52750105],
#        [0.52448314],
#        [0.5233178 ],
#        [0.5235228 ],
#        [0.52469385],
#        [0.52630675],
#        [0.5277619 ],
#        [0.5288303 ],
#        [0.5293708 ],
#        [0.52924836],
#        [0.52820337],
#        [0.52621686],
#        [0.52348393],
#        [0.5202714 ],
#        [0.5171778 ],
#        [0.51505554],
#        [0.51368314],
#        [0.51239103],
#        [0.51064956],
#        [0.5082377 ],
#        [0.50511086],
#        [0.5014535 ],
#        [0.4975494 ],
#        [0.49359494],
#        [0.4897775 ],
#        [0.48624897],
#        [0.48299342],
#        [0.47987103],
#        [0.47663933],
#        [0.4731604 ],
#        [0.46938902],
#        [0.46527803],
#        [0.46080473],
#        [0.45601287],
#        [0.4510027 ],
#        [0.44592118],
#        [0.4409321 ],
#        [0.43626386],
#        [0.43211627],
#        [0.42869103],
#        [0.42593858],
#        [0.42375183],
#        [0.4219892 ],
#        [0.42050445],
#        [0.41919902],
#        [0.41795367],
#        [0.41666532],
#        [0.415246  ],
#        [0.41368127],
#        [0.4119832 ],
#        [0.41019034],
#        [0.40829325],
#        [0.40627807],
#        [0.40411586],
#        [0.40174574],
#        [0.39908487],
#        [0.3960924 ],
#        [0.3927554 ],
#        [0.38907748],
#        [0.38510394],
#        [0.38092917],
#        [0.37666583],
#        [0.37237912],
#        [0.36812025],
#        [0.36394507],
#        [0.35987338],
#        [0.3558944 ],
#        [0.35199648],
#        [0.3481683 ],
#        [0.3443954 ],
#        [0.3406513 ],
#        [0.3368807 ],
#        [0.3330412 ],
#        [0.32906553],
#        [0.3248853 ],
#        [0.32032138],
#        [0.31513178],
#        [0.30917978],
#        [0.30217996],
#        [0.29368588],
#        [0.2826839 ],
#        [0.2690684 ],
#        [0.25261813],
#        [0.23354058],
#        [0.21223432],
#        [0.19055083],
#        [0.17010224],
#        [0.15190971],
#        [0.13663119],
#        [0.12450588],
#        [0.115481  ],
#        [0.10933777],
#        [0.10572653],
#        [0.10418315],
#        [0.1044547 ],
#        [0.10645533],
#        [0.11043209],
#        [0.11635752],
#        [0.12403096],
#        [0.13336907],
#        [0.14422667],
#        [0.15636283],
#        [0.16948546],
#        [0.18342145],
#        [0.1978637 ],
#        [0.21238427],
#        [0.22659169],
#        [0.23997703],
#        [0.25175524],
#        [0.26153073],
#        [0.26948613],
#        [0.27595702],
#        [0.2812733 ],
#        [0.2856631 ],
#        [0.28929287],
#        [0.2923981 ],
#        [0.29517624],
#        [0.29767364],
#        [0.29988098],
#        [0.30177104],
#        [0.30334103],
#        [0.30460414],
#        [0.3055664 ],
#        [0.30623674],
#        [0.30661616],
#        [0.30671334],
#        [0.30655158],
#        [0.3061751 ],
#        [0.30562893],
#        [0.30494243],
#        [0.30415076],
#        [0.3032563 ],
#        [0.30224174],
#        [0.3010649 ],
#        [0.299726  ],
#        [0.29824537],
#        [0.29664153],
#        [0.29493612],
#        [0.2931329 ],
#        [0.29123563],
#        [0.28925914],
#        [0.28721434],
#        [0.28512967],
#        [0.28301853],
#        [0.2809201 ],
#        [0.27884373],
#        [0.27685386],
#        [0.27501413],
#        [0.27337915],
#        [0.2719981 ],
#        [0.27093673],
#        [0.27025306],
#        [0.26998484],
#        [0.27014557],
#        [0.27073067],
#        [0.271712  ],
#        [0.27305055],
#        [0.27469406],
#        [0.2765594 ],
#        [0.2784911 ],
#        [0.28037733],
#        [0.28215912],
#        [0.28379476],
#        [0.28528118],
#        [0.28664654],
#        [0.28791925],
#        [0.28909633],
#        [0.2901562 ],
#        [0.29109   ],
#        [0.29190487],
#        [0.29262704],
#        [0.29328576],
#        [0.29391873],
#        [0.29458237],
#        [0.29533613],
#        [0.2962315 ],
#        [0.29731357],
#        [0.29859784],
#        [0.3000646 ],
#        [0.30168056],
#        [0.30340314],
#        [0.30538622],
#        [0.308181  ],
#        [0.3128299 ],
#        [0.32053137],
#        [0.33288747],
#        [0.35036957],
#        [0.3725403 ],
#        [0.398467  ],
#        [0.42616916],
#        [0.45425588],
#        [0.48243308],
#        [0.51053506],
#        [0.53865016],
#        [0.56681657],
#        [0.5943392 ],
#        [0.6204334 ],
#        [0.64447165],
#        [0.66570795],
#        [0.68427783],
#        [0.6997633 ],
#        [0.7120795 ],
#        [0.71920276],
#        [0.7203598 ],
#        [0.71545136],
#        [0.70560557],
#        [0.6922667 ],
#        [0.6771883 ],
#        [0.6620208 ],
#        [0.64791095],
#        [0.6355213 ],
#        [0.6256236 ],
#        [0.6190466 ],
#        [0.61693734],
#        [0.61998713],
#        [0.62849045],
#        [0.64176875],
#        [0.6600101 ],
#        [0.6824052 ],
#        [0.708346  ],
#        [0.73730415],
#        [0.7679318 ],
#        [0.7994022 ],
#        [0.8307133 ],
#        [0.8608086 ],
#        [0.8882188 ]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.05953089])

# %%
scale_factor = 1/0.05953089
y_predicted = y_predicted * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test , 'b' ,  label = 'Original Price')
plt.plot(y_predicted , 'r' ,  label = 'Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
